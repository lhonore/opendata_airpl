# %% [markdown]
# # Indice ATMO du jour par EPCI
#
# source des données: opendata d'air pays de la loire

# %%
# importer des librairies
import requests
from datetime import date, datetime
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import contextily as cx
import locale

# %%
# Pour mettre la date en français
locale.setlocale(locale.LC_ALL, 'fr_FR.UTF-8')
# Out:
# 'fr_FR.UTF-8'

# %%
# Récupération de la date du jour
day = date.today()
day
# Out:
# datetime.date(2021, 3, 13)

# %%
url_legende = 'https://data.airpl.org/api/v1/indice/qualificatif/'
r = requests.get(url_legende)
legendes = r.json()
legendes
# Out:
# [{'valeur': 1, 'qualificatif': 'bon', 'couleur': '#50f0e6'},
#  {'valeur': 2, 'qualificatif': 'moyen', 'couleur': '#50ccaa'},
#  {'valeur': 3, 'qualificatif': 'degradé', 'couleur': '#f0e641'},
#  {'valeur': 4, 'qualificatif': 'mauvais', 'couleur': '#ff5050'},
#  {'valeur': 5, 'qualificatif': 'très mauvais', 'couleur': '#960032'},
#  {'valeur': 6, 'qualificatif': 'extrêmement mauvais', 'couleur': '#7d2181'},
#  {'valeur': 100, 'qualificatif': 'indisponible', 'couleur': '#DDDDDD'},
#  {'valeur': 101, 'qualificatif': 'événement', 'couleur': '#888888'}]

# %%
# Récupération des données sur l'opendata d'airpl
url_data = f'https://data.airpl.org/api/v1/indice/epci/?export=json&date={day.isoformat()}'
url_data
# Out:
# 'https://data.airpl.org/api/v1/indice/epci/?export=json&date=2021-03-13'

# %%
# Création d'un dataframe avec les données
r = requests.get(url_data)
data = pd.DataFrame(r.json().get('results')).set_index('epci')
data.head(5)
# Out:
#               id        date                                      epci_nom  \
# epci
# 200000438  28259  2021-03-13  CC du Pays de Pontchâteau St-Gildas-des-Bois
# 200023778  28260  2021-03-13          CC du Pays de St Gilles-Croix-de-Vie
# 200033298  28261  2021-03-13                               CC des Coëvrons
# 200040475  28262  2021-03-13                      CC Loué - Brûlon - Noyen
# 200042182  28263  2021-03-13                       CC du Mont des Avaloirs
#
#                  epci_nom_com_1         epci_nom_com_2  \
# epci
# 200000438  Pays de Pont-Château  Saint-Gildas-des-Bois
# 200023778  Pays de Saint Gilles           Croix de Vie
# 200033298              Coëvrons                   None
# 200040475     Loué-Noyen-Brûlon                   None
# 200042182     Mont des Avaloirs                   None
#
#                    epci_nom_com_3 indice  valeur  couleur  \
# epci
# 200000438  Communauté de communes  moyen       2  #50ccaa
# 200023778  Communauté de communes  moyen       2  #50ccaa
# 200033298  Communauté de communes  moyen       2  #50ccaa
# 200040475  Communauté de communes  moyen       2  #50ccaa
# 200042182  Communauté de communes  moyen       2  #50ccaa
#
#                                                  sous_indice       type
# epci
# 200000438  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 200023778  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 200033298  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 200040475  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 200042182  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision

# %%
# Récupération du geojson EPCI, et création d'un géodataframe
url_epci = 'https://data.airpl.org/api/v1/indice/epci-geojson/'
epci = gpd.read_file(url_epci).set_index('id')
epci.head(5)
# Out:
#                                                          nom  \
# id
# 248500662                             CC du Pays de Mortagne
# 244400644  CA de la Région Nazairienne et de l'Estuaire (...
# 248500621                            CC du Pays des Herbiers
# 248500589                CA La Roche sur Yon - Agglomération
# 200071678                      CA Agglomération du Choletais
#
#                                                     geometry
# id
# 248500662  MULTIPOLYGON (((-0.89219 46.97608, -0.89245 46...
# 244400644  MULTIPOLYGON (((-2.18040 47.27588, -2.18040 47...
# 248500621  MULTIPOLYGON (((-1.13119 46.83898, -1.13009 46...
# 248500589  MULTIPOLYGON (((-1.59712 46.67610, -1.59704 46...
# 200071678  MULTIPOLYGON (((-0.89219 46.97608, -0.89219 46...

# %%
# Jointure entre les deux dataframes
data = epci.join(data, lsuffix="_geo").set_index('id')
data.head(5)
# Out:
#                                                      nom  \
# id
# 28329                             CC du Pays de Mortagne
# 28304  CA de la Région Nazairienne et de l'Estuaire (...
# 28328                            CC du Pays des Herbiers
# 28327                CA La Roche sur Yon - Agglomération
# 28278                      CA Agglomération du Choletais
#
#                                                 geometry        date  \
# id
# 28329  MULTIPOLYGON (((-0.89219 46.97608, -0.89245 46...  2021-03-13
# 28304  MULTIPOLYGON (((-2.18040 47.27588, -2.18040 47...  2021-03-13
# 28328  MULTIPOLYGON (((-1.13119 46.83898, -1.13009 46...  2021-03-13
# 28327  MULTIPOLYGON (((-1.59712 46.67610, -1.59704 46...  2021-03-13
# 28278  MULTIPOLYGON (((-0.89219 46.97608, -0.89219 46...  2021-03-13
#
#                                                 epci_nom  \
# id
# 28329                             CC du Pays de Mortagne
# 28304  CA de la Région Nazairienne et de l'Estuaire (...
# 28328                            CC du Pays des Herbiers
# 28327                CA La Roche sur Yon - Agglomération
# 28278                      CA Agglomération du Choletais
#
#                    epci_nom_com_1 epci_nom_com_2          epci_nom_com_3  \
# id
# 28329            Pays de Mortagne           None  Communauté de communes
# 28304        CARENE Saint-Nazaire           None           Agglomération
# 28328           Pays des Herbiers           None  Communauté de communes
# 28327            La Roche-sur-Yon           None           Agglomération
# 28278  Agglomération du Choletais           None                    None
#
#       indice  valeur  couleur  \
# id
# 28329  moyen       2  #50ccaa
# 28304  moyen       2  #50ccaa
# 28328  moyen       2  #50ccaa
# 28327  moyen       2  #50ccaa
# 28278  moyen       2  #50ccaa
#
#                                              sous_indice       type
# id
# 28329  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 28304  [{'polluant_name': 'PM25', 'polluant': '39', '...  prevision
# 28328  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 28327  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision
# 28278  [{'polluant_name': 'O3', 'polluant': '08', 'in...  prevision

# %%
from matplotlib.patches import Patch
# Création de la carte
fig, ax = plt.subplots(figsize=(20,10))
data.to_crs('EPSG:3857').boundary.plot(ax=ax, color='white')
data.to_crs('EPSG:3857').plot(ax=ax, color=data.couleur, alpha=0.7, legend=True)
cx.add_basemap(ax=ax, crs='EPSG:3857', source=cx.providers.CartoDB.Positron)
ax.set_title(f"Indice ATMO par EPCI du {datetime.strftime(day, '%A %d %B %Y')}", fontsize=20)
ax.set_axis_off()
lgd = ax.legend(
    handles=[
        Patch(
            facecolor=e.get('couleur'),
            edgecolor=None,
            label=e.get('qualificatif')
        ) for e in legendes], loc="lower right")
plt.show()
